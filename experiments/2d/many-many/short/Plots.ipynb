# %% [markdown]
# ### False Positives

# %%
models = ['Original', 'SMPV', 'NNPV', 'SOFTMAXP', 'NNP', 'SMDB', 'NNDB']
false_positives = [0, 23, 21, 0, 1, 7, 5]

pd.DataFrame(false_positives, index=models, columns=['Number of False Positives']).plot(kind='bar', title='False Positives During Testing', color='red')
